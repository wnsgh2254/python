# %% [markdown]
# # 문제 1.
# - 문자 10개를 저장할 수 있는 리스트를 만들고 10개의 문자를 입력받아 입력받은 문자를 이어서 출력하는 프로그램을 작성하시오.
# - 입력 예: A B C D E F G H I J
# - 출력 예: ABCDEFGHIJ

# %%
a = ''
while len(a) < 10:
  a += input("문자를 입력하세요 : ")

print(a)

# %% [markdown]
# # 문제 2.
# - 10개의 문자를 입력받아서 첫 번째 네 번째 일곱 번째 입력받은 문자를 차례로 출력하는 프로그램을 작성하시오.
# - 입력 예: A B C D E F G H I J
# - 출력 예: A D G

# %%
a = ''
while len(a) < 10:
  a += input("문자를 입력하세요 : ")

print(a[0],end=' ')
print(a[3],end=' ')
print(a[6])
# Out:
# 문자를 입력하세요 : A
# 문자를 입력하세요 : B
# 문자를 입력하세요 : C
# 문자를 입력하세요 : D
# 문자를 입력하세요 : E
# 문자를 입력하세요 : F
# 문자를 입력하세요 : G
# 문자를 입력하세요 : H
# 문자를 입력하세요 : I
# 문자를 입력하세요 : J
# A D G

# %% [markdown]
# # 문제 3.
# - 빈 리스트을 선언하고 정수를 차례로 입력받다가 0 이 입력되면 0 을 제외하고 그 때까지 입력된 정수를 가장 나중에 입력된 정수부터 차례대로 출력하는 프로그램을 작성하시오.
# - 입력 예:
#     * 3
#     * 5
#     * 10
#     * 55
#     * 0
# - 출력 예: 55 10 5 3

# %%
a = []
while True:
  num = int(input("정수를 입력하세요 : "))
  if num == 0:
    break
  a.append(num)
  
print(a[::-1], end=' ')
# Out:
# 정수를 입력하세요 : 3
# 정수를 입력하세요 : 5
# 정수를 입력하세요 : 10
# 정수를 입력하세요 : 55
# 정수를 입력하세요 : 0
# [55, 10, 5, 3]

# %% [markdown]
# # 문제 4.
# - 1반부터 6반까지의 평균점수를 저장한 후 두 반의 반 번호를 입력받아 두 반 평균점수의 합을 출력하는 프로그램을 작성하시오.
# - 반별 평균점수는 초기값으로 1반부터 차례로 85.6 79.5 83.1 80.0 78.2 75.0으로 초기화하고,
# - 출력은 소수 두 번째 자리에서 반올림하여 소수 첫째자리까지 한다.
# - 입력 예: 1 3 (1반 3반을 의미)
# - 출력 예: 168.7

# %%
class1 = 85.6
class2 = 79.5
class3 = 83.1
class4 = 80.0
class5 = 78.2
class6 = 75.0

school = [class1,class2,class3,class4,class5,class6]

a = int(input("반을 입력하세요 : ")) 
b = int(input("반을 입력하세요 : ")) 



print(round(school[a-1]+school[b-1], 1))

# %% [markdown]
# # 문제 5.
# - 10개의 정수를 입력받아 그 중 가장 작은 수를 출력하는 프로그램을 작성하시오.
# - 입력 예: 5 10 8 55 6 31 12 24 61 2
# - 출력 예: 2

# %%
a = []
while len(a) < 10:
  a.append(int(input("정수를 입력하세요 : ")))
print(min(a))
# Out:
# 정수를 입력하세요 : 1
# 정수를 입력하세요 : 2
# 정수를 입력하세요 : 3
# 정수를 입력하세요 : 5
# 정수를 입력하세요 : 7
# 정수를 입력하세요 : 8
# 정수를 입력하세요 : 7
# 정수를 입력하세요 : 6
# 정수를 입력하세요 : 5
# 정수를 입력하세요 : 4
# 1

# %% [markdown]
# # 문제 6.
# - 10개의 정수를 입력받아 100 미만의 수 중 가장 큰 수와 100 이상의 수 중 가장 작은 수를 출력하는 프로그램을 작성하시오.
# - 입력 예: 88 123 659 15 443 1 99 313 105 48
# - 출력 예: 99 105

# %%
under = []
over = []

while len(under+over) < 10:
  n = int(input("정수를 입력하세요 : "))
  if n >= 100:
    over.append(n)
  else:
    under.append(n)

print(max(under), end=' ')
print(min(over))
# Out:
# 정수를 입력하세요 : 88
# 정수를 입력하세요 : 123
# 정수를 입력하세요 : 659
# 정수를 입력하세요 : 15
# 정수를 입력하세요 : 443
# 정수를 입력하세요 : 1
# 정수를 입력하세요 : 99
# 정수를 입력하세요 : 313
# 정수를 입력하세요 : 105
# 정수를 입력하세요 : 48
# 99 105

# %% [markdown]
# # 문제 7.
# - 10개의 정수를 입력받아 리스트에 저장한 후 짝수 번째 입력된 값의 합과 홀수 번째 입력된 값의 평균을 출력하는 프로그램을 작성하시오.
# - 평균은 반올림하여 소수첫째자리까지 출력한다.
# - 입력 예: 95 100 88 65 76 89 58 93 77 99
# - 출력 예:
#     * sum : 446
#     * avg : 78.8

# %%
a = []
n1 = 0
n2 = 0
while len(a) < 10:
  n = int(input("정수를 입력하세요 : "))
  a.append(n)
for i in a:
  if a.index(i) % 2 == 0:
        n1 += i
  elif a.index(i) % 2 != 0:
        n2 += i

print("sum : {}".format(n2)) 
print("avg : {}".format(n1/5))
# Out:
# 정수를 입력하세요 : 95
# 정수를 입력하세요 : 100
# 정수를 입력하세요 : 88
# 정수를 입력하세요 : 65
# 정수를 입력하세요 : 76
# 정수를 입력하세요 : 89
# 정수를 입력하세요 : 58
# 정수를 입력하세요 : 93
# 정수를 입력하세요 : 77
# 정수를 입력하세요 : 99
# sum : 446
# avg : 78.8

# %% [markdown]
# # 문제 8.
# - 10개의 정수를 입력받아 리스트에 저장한 후 내림차순으로 정렬하여 출력하시오.
# - 입력 예: 95 100 88 65 76 89 58 93 77 99
# - 출력 예: 100 99 95 93 89 88 77 76 65 58

# %%
a = []

while len(a) < 10:
  n = int(input("정수를 입력하세요: "))
  a.append(n)

print(sorted(a, reverse=True))
# Out:
# 정수를 입력하세요: 95
# 정수를 입력하세요: 100
# 정수를 입력하세요: 88
# 정수를 입력하세요: 65
# 정수를 입력하세요: 76
# 정수를 입력하세요: 89
# 정수를 입력하세요: 58
# 정수를 입력하세요: 93
# 정수를 입력하세요: 77
# 정수를 입력하세요: 99
# [100, 99, 95, 93, 89, 88, 77, 76, 65, 58]
